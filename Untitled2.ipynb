# %%
from openslide import open_slide

# %%
import openslide

# %%
from PIL import Image

# %%
import numpy as np

# %%
import os
data_path = '/lab/deasylab3/Jung/tiger/'
dir_TIFF_images = data_path + "/wsirois/wsi-level-annotations/images/"


imgs_names = os.listdir(dir_TIFF_images)
imgs_names.sort()
imgs_names = [i for i in imgs_names if i.startswith('TCGA')]  
wsi_path = dir_TIFF_images + imgs_names[0]
wsi_path
# Out:
# '/lab/deasylab3/Jung/tiger//wsirois/wsi-level-annotations/images/TCGA-A1-A0SK-01Z-00-DX1.A44D70FA-4D96-43F4-9DD7-A61535786297.tif'

# %%
import tiatoolbox

# %%
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor
# Out:
# |2025-07-29|14:32:31.938| [WARNING] /cluster/home/srivash/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
x_min,y_min,x_max,y_max = 8209,200,59972,34836

# %%
from tiatoolbox.tools.patchextraction import get_patch_extractor
from tiatoolbox.wsicore.wsireader import WSIReader
import numpy as np

# %%
# 1. Open the WSI
wsi = WSIReader.open(wsi_path)
patch_size=(224, 224)
stride=(224, 224)
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor
from tiatoolbox.wsicore.wsireader import WSIReader

def extract_patches_in_bbox(
    slide_path,
    bbox,
    patch_size=(224, 224),
    stride=(224, 224),
    resolution=0,         # or use 1.25 with units="mpp"
    units="level",
    pad_mode="constant",
    pad_value=255,
    min_mask_ratio=0.0,
):
    x_min, y_min, x_max, y_max = bbox
    region = (x_min, y_min, x_max - x_min, y_max - y_min)

    wsi = WSIReader.open(slide_path)

    extractor = SlidingWindowPatchExtractor(
        input_img=wsi,
        patch_size=patch_size,
        stride=stride,
        resolution=resolution,
        units=units,
        pad_mode=pad_mode,
        pad_constant_values=pad_value,
        min_mask_ratio=min_mask_ratio,
        region=region  # restricts extraction to this area
    )

    return [patch for patch in extractor]

# %%
region_width = x_max - x_min
region_height = y_max - y_min

# Crop the WSI at level 0
cropped = wsi.read_rect(
    location=(x_min, y_min),
    size=(region_width, region_height),
    resolution=0,
    units="level"
)
# Out:
# |2025-07-25|17:21:27.036| [WARNING] Metadata: Objective power inferred from microns-per-pixel (MPP).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 region_height = y_max - y_min
#       4 # Crop the WSI at level 0
# ----> 5 cropped = wsi.read_rect(
#       6     location=(x_min, y_min),
#       7     size=(region_width, region_height),
#       8     resolution=0,
#       9     units="level"
#      10 )
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/tiatoolbox/wsicore/wsireader.py:1973, in OpenSlideWSIReader.read_rect(self, location, size, resolution, units, interpolation, pad_mode, pad_constant_values, coord_space, **kwargs)
#    1965 # Resize to correct scale if required
#    1966 im_region = utils.transforms.imresize(
#    1967     img=im_region,
#    1968     scale_factor=post_read_scale,
#    1969     output_size=size,
#    1970     interpolation=interpolation,
#    1971 )
# -> 1973 return utils.transforms.background_composite(image=im_region, alpha=False)
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/tiatoolbox/utils/transforms.py:54, in background_composite(image, fill, alpha)
#      49 image = image.convert("RGBA")
#      51 composite = Image.fromarray(
#      52     np.full([*list(image.size[::-1]), 4], fill, dtype=np.uint8),
#      53 )
# ---> 54 composite.alpha_composite(image)
#      55 if not alpha:
#      56     return np.array(composite.convert("RGB"))
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/Image.py:1878, in Image.alpha_composite(self, im, dest, source)
#    1875     background = self.crop(box)
#    1877 result = alpha_composite(background, overlay)
# -> 1878 self.paste(result, box)
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/Image.py:1816, in Image.paste(self, im, box, mask)
#    1813 else:
#    1814     source = im
# -> 1816 self._ensure_mutable()
#    1818 if mask:
#    1819     mask.load()
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/Image.py:642, in Image._ensure_mutable(self)
#     640 def _ensure_mutable(self) -> None:
#     641     if self.readonly:
# --> 642         self._copy()
#     643     else:
#     644         self.load()
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/Image.py:637, in Image._copy(self)
#     635 def _copy(self) -> None:
#     636     self.load()
# --> 637     self.im = self.im.copy()
#     638     self.readonly = 0
#
# KeyboardInterrupt:

# %%
wsi_dims = wsi.slide_dimensions(resolution=0, units="level")
from tiatoolbox.wsicore.wsireader import WSIReader, VirtualWSIReader
# --- Step 3: Create binary mask from bounding box ---
bbox_mask = np.zeros((wsi_dims[1], wsi_dims[0]), dtype=bool)  # (H, W)
bbox_mask[y_min:y_max, x_min:x_max] = True

# Wrap as a VirtualWSIReader (efficient access at pyramid levels)
mask_reader = VirtualWSIReader(
    bbox_mask,
    info=wsi.info,
    mode="bool"
)

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from tiatoolbox.wsicore.wsireader import WSIReader, VirtualWSIReader
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor


def extract_and_save_patches(
    wsi_path,
    x_min,
    y_min,
    x_max,
    y_max,
    out_dir="tiles",
    patch_size=(224, 224),
    stride=(224, 224),
    min_mask_ratio=0.5,
):
    os.makedirs(out_dir, exist_ok=True)
    csv_path = os.path.join(out_dir, "pipeline_tiles.csv")

    # Step 1: Open WSI
    wsi = WSIReader.open(wsi_path)
    wsi_dims = wsi.slide_dimensions(resolution=0, units="level")  # (W, H)

    # Step 2: Create bounding box binary mask
    bbox_mask = np.zeros((wsi_dims[1], wsi_dims[0]), dtype=bool)  # (H, W)
    bbox_mask[y_min:y_max, x_min:x_max] = True

    # Step 3: Wrap mask with VirtualWSIReader
    mask_reader = VirtualWSIReader(bbox_mask, info=wsi.info, mode="bool")

    # Step 4: Initialize patch extractor
    extractor = SlidingWindowPatchExtractor(
        input_img=wsi,
        patch_size=patch_size,
        stride=stride,
        resolution=0,
        units="level",
        input_mask=mask_reader,
        within_bound=True,
        min_mask_ratio=min_mask_ratio,
    )

    # Step 5: Extract and save patches
    coords = extractor.locations_df[["x", "y"]]
    metadata = []

    for i, patch in enumerate(tqdm(extractor, desc="Extracting patches")):
        x, y = int(coords.iloc[i]["x"]), int(coords.iloc[i]["y"])
        filename = f"tile_{i}_{x}_{y}.png"
        save_path = os.path.join(out_dir, filename)
        Image.fromarray(patch).save(save_path)

        metadata.append({
            "index": i,
            "filename": filename,
            "x": x,
            "y": y
        })

    pd.DataFrame(metadata).to_csv(csv_path, index=False)

    print(f"✅ Saved {len(metadata)} patches to {out_dir}")
    print(f"📄 Patch metadata CSV saved to {csv_path}")

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm

from skimage.color import rgb2hed
from skimage.filters import gaussian, threshold_otsu
from skimage.morphology import remove_small_objects, remove_small_holes

from tiatoolbox.wsicore.wsireader import WSIReader, VirtualWSIReader
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor


def generate_he_mask(wsi, x_min, y_min, x_max, y_max, sigma=1.5, min_size=300):
    """Generate a tissue mask using H&E deconvolution from a bounding box region."""
    # Read region RGB (as NumPy array)
    region = wsi.read_rect(
        location=(x_min, y_min),
        size=(x_max - x_min, y_max - y_min),
        resolution=0,
        units="level"
    )

    # --- H&E Deconvolution on Hematoxylin Channel
    he = rgb2hed(region)
    hema = -he[:, :, 0]
    hema = (hema - np.min(hema)) / (np.max(hema) - np.min(hema))

    # Gaussian filter and Otsu threshold
    smooth = gaussian(hema, sigma=sigma)
    threshold = threshold_otsu(smooth)
    tissue_mask = smooth > threshold

    # Clean up mask
    tissue_mask = remove_small_objects(tissue_mask, min_size=min_size)
    tissue_mask = remove_small_holes(tissue_mask, area_threshold=min_size)

    # Insert into full-resolution binary mask
    full_mask = np.zeros(wsi.slide_dimensions(resolution=0, units="level")[::-1], dtype=bool)
    full_mask[y_min:y_max, x_min:x_max] = tissue_mask.astype(bool)

    return full_mask

# %%
def extract_and_save_patches(
    wsi_path,
    x_min,
    y_min,
    x_max,
    y_max,
    out_dir="tiles",
    patch_size=(224, 224),
    stride=(224, 224),
    min_mask_ratio=0.5,
):
    os.makedirs(out_dir, exist_ok=True)
    csv_path = os.path.join(out_dir, "pipeline_tiles.csv")

    # Load WSI
    wsi = WSIReader.open(wsi_path)

    # Generate H&E-based tissue mask
    tissue_mask = generate_he_mask(wsi, x_min, y_min, x_max, y_max)

    # Wrap mask into VirtualWSIReader
    mask_reader = VirtualWSIReader(tissue_mask, info=wsi.info, mode="bool")

    # Initialize patch extractor with tissue mask
    extractor = SlidingWindowPatchExtractor(
        input_img=wsi,
        patch_size=patch_size,
        stride=stride,
        resolution=0,
        units="level",
        input_mask=mask_reader,
        within_bound=True,
        min_mask_ratio=min_mask_ratio,
    )

    # Extract patches and save
    coords = extractor.locations_df[["x", "y"]]
    metadata = []

    for i, patch in enumerate(tqdm(extractor, desc="Extracting tissue patches")):
        x, y = int(coords.iloc[i]["x"]), int(coords.iloc[i]["y"])
        filename = f"tile_{i}_{x}_{y}.png"
        save_path = os.path.join(out_dir, filename)
        Image.fromarray(patch).save(save_path)

        metadata.append({
            "index": i,
            "filename": filename,
            "x": x,
            "y": y
        })

    pd.DataFrame(metadata).to_csv(csv_path, index=False)
    print(f"✅ Saved {len(metadata)} patches to {out_dir}")
    print(f"📄 Patch metadata CSV saved to {csv_path}")

# %%
import os
import numpy as np
from tqdm import tqdm
from PIL import Image
import pandas as pd
from tiatoolbox.wsicore.wsireader import WSIReader
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor
from tiatoolbox.wsicore.wsireader import VirtualWSIReader

# Inputs

output_dir = "tiles"
patch_size = (224, 224)
stride = (224, 224)
min_mask_ratio = 0.5
x_min, y_min, x_max, y_max = 8209, 200, 59972, 34836

# 1. Open the WSI
wsi = WSIReader.open(input_img=wsi_path)

# 2. Crop region + mask
region_width = x_max - x_min
region_height = y_max - y_min
region_img = wsi.read_rect(location=(x_min, y_min), size=(region_width, region_height), resolution=0, units="level")

# 3. Resize tissue mask for cropped region
# You must already have a binary mask (full resolution) as a NumPy array named `full_mask`
region_mask = full_mask[y_min:y_max, x_min:x_max]

# 4. Create VirtualWSIReader for cropped region & mask
wsi_cropped = VirtualWSIReader(region_img, info=wsi.info)
mask_cropped = VirtualWSIReader(region_mask, info=wsi.info, mode="bool")

# 5. Setup patch extractor
extractor = SlidingWindowPatchExtractor(
    input_img=wsi_cropped,
    patch_size=patch_size,
    stride=stride,
    resolution=0,
    units="level",
    input_mask=mask_cropped,
    within_bound=True,
    min_mask_ratio=min_mask_ratio,
)

# 6. Extract and save patches
os.makedirs(output_dir, exist_ok=True)
csv_path = os.path.join(output_dir, "pipeline_tiles.csv")
coords = extractor.locations_df[["x", "y"]]
metadata = []

for i, patch in enumerate(tqdm(extractor, desc="Extracting patches")):
    x, y = int(coords.iloc[i]["x"]), int(coords.iloc[i]["y"])
    filename = f"tile_{i}_{x+x_min:05d}_{y+y_min:05d}.png"
    save_path = os.path.join(output_dir, filename)
    Image.fromarray(patch).save(save_path)
    metadata.append({"index": i, "filename": filename, "x": x + x_min, "y": y + y_min})

# 7. Save metadata
df = pd.DataFrame(metadata)
df.to_csv(csv_path, index=False)
print(f"✅ Saved {len(metadata)} patches to {output_dir}")
# Out:
# |2025-07-25|17:38:41.965| [WARNING] /cluster/home/srivash/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
#
# |2025-07-25|17:38:42.535| [WARNING] Metadata: Objective power inferred from microns-per-pixel (MPP).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 28
#      24 region_img = wsi.read_rect(location=(x_min, y_min), size=(region_width, region_height), resolution=0, units="level")
#      26 # 3. Resize tissue mask for cropped region
#      27 # You must already have a binary mask (full resolution) as a NumPy array named `full_mask`
# ---> 28 region_mask = full_mask[y_min:y_max, x_min:x_max]
#      30 # 4. Create VirtualWSIReader for cropped region & mask
#      31 wsi_cropped = VirtualWSIReader(region_img, info=wsi.info)
#
# NameError: name 'full_mask' is not defined

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from tiatoolbox.wsicore.wsireader import WSIReader, VirtualWSIReader
from tiatoolbox.tools.patchextraction import SlidingWindowPatchExtractor

def extract_and_save_patches(
    wsi_path,
    x_min,
    y_min,
    x_max,
    y_max,
    out_dir="tiles",
    patch_size=(224, 224),
    stride=(224, 224),
    min_mask_ratio=0.5,
):
    os.makedirs(out_dir, exist_ok=True)
    csv_path = os.path.join(out_dir, "pipeline_tiles.csv")

    # Step 1: Open WSI
    wsi = WSIReader.open(wsi_path)
    wsi_dims = wsi.slide_dimensions(resolution=0, units="level")  # (W, H)

    # Step 2: Create bounding box binary mask
    bbox_mask = np.zeros((wsi_dims[1], wsi_dims[0]), dtype=bool)  # (H, W)
    bbox_mask[y_min:y_max, x_min:x_max] = True

    # Step 3: Wrap mask with VirtualWSIReader
    mask_reader = VirtualWSIReader(bbox_mask, info=wsi.info, mode="bool")

    # Step 4: Initialize patch extractor
    extractor = SlidingWindowPatchExtractor(
        input_img=wsi,
        patch_size=patch_size,
        stride=stride,
        resolution=0,
        units="level",
        input_mask=mask_reader,
        within_bound=True,
        min_mask_ratio=min_mask_ratio,
    )

    # Step 5: Extract and save patches
    coords = extractor.locations_df[["x", "y"]]
    metadata = []

    for i, patch in enumerate(tqdm(extractor, desc="Extracting patches")):
        x, y = int(coords.iloc[i]["x"]), int(coords.iloc[i]["y"])
        filename = f"tile_{i}_{x}_{y}.png"
        save_path = os.path.join(out_dir, filename)
        Image.fromarray(patch).save(save_path)

        # Read matching region from the binary mask to calculate tissue ratio
        mask_patch = mask_reader.read_rect(location=(x, y),
                                           size=patch_size,
                                           resolution=0,
                                           units="level")

        tissue_ratio = np.mean(mask_patch.astype(np.float32))  # [0.0, 1.0]

        metadata.append({
            "index": i,
            "filename": filename,
            "x": x,
            "y": y,
            "tissue_ratio": tissue_ratio
        })

    # Step 6: Save metadata
    pd.DataFrame(metadata).to_csv(csv_path, index=False)

    print(f"✅ Saved {len(metadata)} patches to {out_dir}")
    print(f"📄 Patch metadata CSV saved to {csv_path}")

# %%
x_min,y_min,x_max,y_max = 8209,200,59972,34836

# %%
extract_and_save_patches(
    wsi_path,
    x_min,
    y_min,
    x_max,
    y_max,
    out_dir="Output5",
    patch_size=(224, 224),
    stride=(224, 224),
    min_mask_ratio=0.5,
)
# Out:
# |2025-07-29|14:32:44.341| [WARNING] Metadata: Objective power inferred from microns-per-pixel (MPP).
#
# xtracting patches:  19%|██████████▍                                             | 6657/35804 [16:29<1:12:14,  6.72it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 extract_and_save_patches(
#       2     wsi_path,
#       3     x_min,
#       4     y_min,
#       5     x_max,
#       6     y_max,
#       7     out_dir="Output5",
#       8     patch_size=(224, 224),
#       9     stride=(224, 224),
#      10     min_mask_ratio=0.5,
#      11 )
#
# Cell In[10], line 54, in extract_and_save_patches(wsi_path, x_min, y_min, x_max, y_max, out_dir, patch_size, stride, min_mask_ratio)
#      52 filename = f"tile_{i}_{x}_{y}.png"
#      53 save_path = os.path.join(out_dir, filename)
# ---> 54 Image.fromarray(patch).save(save_path)
#      56 # Read matching region from the binary mask to calculate tissue ratio
#      57 mask_patch = mask_reader.read_rect(location=(x, y),
#      58                                    size=patch_size,
#      59                                    resolution=0,
#      60                                    units="level")
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/Image.py:2588, in Image.save(self, fp, format, **params)
#    2585     fp = cast(IO[bytes], fp)
#    2587 try:
# -> 2588     save_handler(self, fp, filename)
#    2589 except Exception:
#    2590     if open_fp:
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1497, in _save(im, fp, filename, chunk, save_all)
#    1491     single_im = _write_multiple_frames(
#    1492         im, fp, chunk, mode, rawmode, default_image, append_images
#    1493     )
#    1494 if single_im:
#    1495     ImageFile._save(
#    1496         single_im,
# -> 1497         cast(IO[bytes], _idat(fp, chunk)),
#    1498         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1499     )
#    1501 if info:
#    1502     for info_chunk in info.chunks:
#
# File ~/miniforge3/envs/tiatoolbox/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1132, in _idat.__init__(self, fp, chunk)
#    1129 class _idat:
#    1130     # wrap output from the encoder in IDAT chunks
# -> 1132     def __init__(self, fp: IO[bytes], chunk: Callable[..., None]) -> None:
#    1133         self.fp = fp
#    1134         self.chunk = chunk
#
# KeyboardInterrupt:

# %%
metadata =[]
patch_size=(224, 224)
stride=(224, 224)
out_dir = "patches"
# Step 4: Initialize patch extractor
extractor = SlidingWindowPatchExtractor(
    input_img=wsi_path,
    patch_size=patch_size,
    stride=stride,
    resolution=0,
    units="level",
    input_mask="otsu",
    within_bound=True,
    min_mask_ratio=0.5,
)

# Step 5: Extract and save patches
coords = extractor.locations_df[["x", "y"]]
metadata = []

for i, patch in enumerate(tqdm(extractor, desc="Extracting patches")):
    x, y = int(coords.iloc[i]["x"]), int(coords.iloc[i]["y"])
    filename = f"tile_{i}_{x}_{y}.png"
    save_path = os.path.join(out_dir, filename)
    Image.fromarray(patch).save(save_path)

    # Read matching region from the binary mask to calculate tissue ratio
    mask_patch = mask_reader.read_rect(location=(x, y),
                                       size=patch_size,
                                       resolution=0,
                                       units="level")

    tissue_ratio = np.mean(mask_patch.astype(np.float32))  # [0.0, 1.0]

    metadata.append({
        "index": i,
        "filename": filename,
        "x": x,
        "y": y,
        "tissue_ratio": tissue_ratio
    })

# Step 6: Save metadata
pd.DataFrame(metadata).to_csv(csv_path, index=False)
# Out:
# |2025-07-29|15:44:01.909| [WARNING] Metadata: Objective power inferred from microns-per-pixel (MPP).
# |2025-07-29|15:44:01.912| [WARNING] Read: Scale > 1.This means that the desired resolution is higher than the WSI baseline (maximum encoded resolution). Interpolation of read regions may occur.

# %%
import numpy as np

def create_bbox_mask(wsi_width, wsi_height, x_min, y_min, x_max, y_max, value=1):
    """
    Create a binary mask with a filled bounding box.

    Args:
        wsi_width (int): Width of the WSI.
        wsi_height (int): Height of the WSI.
        x_min, y_min, x_max, y_max (int): Bounding box coordinates.
        value (int): Value to fill inside the bounding box (default: 1).
                     Use 255 if using for visualization or OpenCV.

    Returns:
        np.ndarray: Binary mask (H, W) with bbox region filled.
    """
    mask = np.zeros((wsi_height, wsi_width), dtype=np.uint8)
    mask[y_min:y_max, x_min:x_max] = value
    return mask

# %%
mask_1 = create_bbox_mask(wsi_width, wsi_height, x_min, y_min, x_max, y_max, value=1)
